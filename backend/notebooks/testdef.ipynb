# %%
import pandas as pd
import numpy as np
from ScanResult import *
from data_scan import *
from apply_scan_results import *

# %%
np.random.seed(42)
rows = 50

# Create sample data with 10 columns.
data = {
    "num1": np.random.randint(0, 100, size=rows),
    "num2": np.random.randn(rows) * 10,
    "cat1": np.random.choice(["apple", "banana", "cherry"], size=rows),
    "cat2": np.random.choice(["red", "green", "blue"], size=rows),
    "num3": np.random.uniform(0, 50, size=rows),
    "num4": np.random.randint(0, 200, size=rows),
    "text": [f"Sample {i}" for i in range(rows)],
    "bool": np.random.choice([True, False], size=rows),
    "num5": np.random.randn(rows) * 5,
    "cat3": np.random.choice(["X", "Y", "Z"], size=rows)
}
df = pd.DataFrame(data)

for col in ["num2", "num3", "text"]:
    missing_indices = np.random.choice(df.index, size=5, replace=False)
    df.loc[missing_indices, col] = np.nan

df.loc[10] = df.loc[0]
df.loc[20] = df.loc[0]

df1 = df.copy()
df2 = df.copy()
df
# Out:
#     num1       num2    cat1   cat2       num3  num4       text   bool  \
# 0     51 -20.267196  cherry    red  33.606777    98   Sample 0   True
# 1     92  11.194236  banana    red        NaN   152   Sample 1  False
# 2     14   7.791926  cherry    red  11.881877    92   Sample 2   True
# 3     71 -11.010978   apple   blue  36.410817   145   Sample 3  False
# 4     60  11.302282   apple  green  18.389157   127   Sample 4   True
# 5     20        NaN  banana    red        NaN   109   Sample 5  False
# 6     82  -3.864730  cherry    red  31.676486    81   Sample 6  False
# 7     86 -11.587702  cherry    red  26.788734   193   Sample 7  False
# 8     74   5.661128  banana   blue   4.514489    53   Sample 8   True
# 9     74  -7.044535  cherry   blue  41.765125   162   Sample 9  False
# 10    51 -20.267196  cherry    red  33.606777    98   Sample 0   True
# 11    99  -3.531167   apple   blue   9.325926   168  Sample 11  False
# 12    23  -4.614657  cherry    red   2.038757   160  Sample 12   True
# 13     2   0.666573  cherry  green  29.544647    67  Sample 13  False
# 14    21  -1.762857  banana    red  33.878218    32  Sample 14   True
# 15    52  12.008928  banana    red   0.829391   141  Sample 15   True
# 16     1   6.983989   apple   blue  25.604653    20  Sample 16  False
# 17    87  -1.716288  cherry  green  11.324789    47  Sample 17   True
# 18    29  -9.071866  cherry   blue  32.258640   147  Sample 18   True
# 19    37  11.886257  cherry   blue   8.718321   127        NaN  False
# 20    51 -20.267196  cherry    red  33.606777    98   Sample 0   True
# 21    63        NaN   apple    red  19.336767   134  Sample 21   True
# 22    59   2.634860  banana    red  46.836499   194  Sample 22   True
# 23    20  16.417711   apple  green   6.876047   144  Sample 23  False
# 24    32   4.608163  cherry    red  17.053318   127        NaN   True
# 25    75        NaN  cherry  green   5.673676    32  Sample 25  False
# 26    57 -15.099573   apple  green  46.234681   175  Sample 26   True
# 27    21   7.215025  cherry   blue  43.866968   186  Sample 27   True
# 28    88  -8.434199  cherry  green        NaN   114  Sample 28   True
# 29    48  -5.133254   apple   blue  32.999202   118  Sample 29  False
# 30    90  -0.435368   apple    red  40.861110    21  Sample 30   True
# 31    58  -2.753009  cherry    red  27.760041   157        NaN   True
# 32    41 -15.630668  cherry    red  26.482529    37  Sample 32  False
# 33    91  -7.956310  cherry    red  12.092615   108  Sample 33   True
# 34    59   9.305844  banana   blue   4.655138    50  Sample 34  False
# 35    79   6.777674  banana    red  44.860788   181  Sample 35  False
# 36    14   6.984403  banana  green  45.020903     7        NaN   True
# 37    61   1.736021   apple  green  31.655073    26  Sample 37  False
# 38    61   6.622845  banana  green  16.951490    26  Sample 38   True
# 39    46   2.411222   apple   blue  17.460479    20  Sample 39  False
# 40    61  -1.682051   apple    red  36.297784    29        NaN  False
# 41    50  11.647686  banana    red        NaN    96  Sample 41   True
# 42    54        NaN  banana    red  44.354321    27  Sample 42  False
# 43    63  -7.696678  banana   blue  38.993777   110  Sample 43  False
# 44     2  12.121723  cherry  green        NaN   191  Sample 44  False
# 45    50  12.334968  banana  green   4.206998   196  Sample 45  False
# 46     6 -15.741553  cherry    red   8.081436    60  Sample 46  False
# 47    20   6.379529   apple  green  44.927709    47  Sample 47   True
# 48    72 -20.444230  cherry  green  30.321453   146  Sample 48  False
# 49    38  10.694809  banana   blue   0.459853     3  Sample 49   True
#
#          num5 cat3
# 0    0.291044    Y
# 1   -5.714851    Y
# 2    1.788937    X
# 3    2.803923    X
# 4    5.415256    X
# 5    5.269010    X
# 6   -6.888347    X
# 7   -4.689125    Z
# 8    2.575176    Z
# 9    2.568930    X
# 10   0.291044    Y
# 11  19.263657    X
# 12   2.854453    Z
# 13   5.677828    Z
# 14   4.770009    Y
# 15   3.256956    Z
# 16  -1.576346    X
# 17   3.794846    Y
# 18  -3.864126    X
# 19  -1.184093    X
# 20   0.291044    Y
# 21   0.409371    X
# 22  11.573293    Z
# 23  -9.336326    X
# 24   3.431301    Y
# 25  -8.063579    Y
# 26  -2.359659    Y
# 27   5.444753    X
# 28   0.321400    Y
# 29  -5.388724    Y
# 30  -3.576519    X
# 31   3.397989    Z
# 32  -3.651833    X
# 33   1.082293    Y
# 34   0.227859    Y
# 35  -3.258002    X
# 36  10.719720    Z
# 37   3.169595    Y
# 38 -10.125713    Y
# 39   0.932272    Y
# 40  -3.308932    X
# 41   4.262167    Y
# 42  -3.962604    Z
# 43  -0.573682    Y
# 44   2.524936    Y
# 45   4.328776    Z
# 46  -6.001482    Y
# 47  -1.672506    X
# 48  -2.374727    X
# 49  -3.266646    X

# %%
scan_results = []
scan_results.extend(scan_df_for_duplicates(df1))
scan_results.extend(scan_df_for_missing(df1))
scan_results.extend(scan_df_for_outliers(df1))
scan_results.extend(scan_df_for_categorical(df1))

scan_results.extend(scan_df_for_target(df1, target=51))

scan_results
# Out:
# [ScanResult(row=10, col=-1, message='Row 11 is duplicated', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Duplication Remover', description='Remove the duplicated rows', cleaner='remove', cleaner_id=0, activate=True, data=None), ScanResultAction(title='Duplication Remover', description='Keep the duplicated rows', cleaner='keep', cleaner_id=1, activate=True, data=None)]),
#  ScanResult(row=20, col=-1, message='Row 21 is duplicated', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Duplication Remover', description='Remove the duplicated rows', cleaner='remove', cleaner_id=2, activate=True, data=None), ScanResultAction(title='Duplication Remover', description='Keep the duplicated rows', cleaner='keep', cleaner_id=3, activate=True, data=None)]),
#  ScanResult(row=1, col=num3, message='Missing value in row 2, column 'num3'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with mean value', cleaner='mean', cleaner_id=0, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with median value', cleaner='median', cleaner_id=1, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=2, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=3, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=4, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=5, activate=True, data=None)]),
#  ScanResult(row=5, col=num2, message='Missing value in row 6, column 'num2'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with mean value', cleaner='mean', cleaner_id=6, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with median value', cleaner='median', cleaner_id=7, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=8, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=9, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=10, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=11, activate=True, data=None)]),
#  ScanResult(row=5, col=num3, message='Missing value in row 6, column 'num3'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with mean value', cleaner='mean', cleaner_id=12, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with median value', cleaner='median', cleaner_id=13, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=14, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=15, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=16, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=17, activate=True, data=None)]),
#  ScanResult(row=19, col=text, message='Missing value in row 20, column 'text'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=18, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=19, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=20, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=21, activate=True, data=None)]),
#  ScanResult(row=21, col=num2, message='Missing value in row 22, column 'num2'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with mean value', cleaner='mean', cleaner_id=22, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with median value', cleaner='median', cleaner_id=23, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=24, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=25, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=26, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=27, activate=True, data=None)]),
#  ScanResult(row=24, col=text, message='Missing value in row 25, column 'text'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=28, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=29, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=30, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=31, activate=True, data=None)]),
#  ScanResult(row=25, col=num2, message='Missing value in row 26, column 'num2'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with mean value', cleaner='mean', cleaner_id=32, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with median value', cleaner='median', cleaner_id=33, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=34, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=35, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=36, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=37, activate=True, data=None)]),
#  ScanResult(row=28, col=num3, message='Missing value in row 29, column 'num3'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with mean value', cleaner='mean', cleaner_id=38, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with median value', cleaner='median', cleaner_id=39, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=40, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=41, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=42, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=43, activate=True, data=None)]),
#  ScanResult(row=31, col=text, message='Missing value in row 32, column 'text'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=44, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=45, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=46, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=47, activate=True, data=None)]),
#  ScanResult(row=36, col=text, message='Missing value in row 37, column 'text'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=48, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=49, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=50, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=51, activate=True, data=None)]),
#  ScanResult(row=40, col=text, message='Missing value in row 41, column 'text'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=52, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=53, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=54, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=55, activate=True, data=None)]),
#  ScanResult(row=41, col=num3, message='Missing value in row 42, column 'num3'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with mean value', cleaner='mean', cleaner_id=56, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with median value', cleaner='median', cleaner_id=57, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=58, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=59, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=60, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=61, activate=True, data=None)]),
#  ScanResult(row=42, col=num2, message='Missing value in row 43, column 'num2'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with mean value', cleaner='mean', cleaner_id=62, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with median value', cleaner='median', cleaner_id=63, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=64, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=65, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=66, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=67, activate=True, data=None)]),
#  ScanResult(row=44, col=num3, message='Missing value in row 45, column 'num3'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with mean value', cleaner='mean', cleaner_id=68, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with median value', cleaner='median', cleaner_id=69, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=70, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=71, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=72, activate=True, data=None), ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=73, activate=True, data=None)]),
#  ScanResult(row=11, col=num5, message='Outlier detected in column 'num5' at row 12', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Outlier Handler', description='Delete the outlier', cleaner='delete', cleaner_id=0, activate=True, data=None), ScanResultAction(title='Outlier Handler', description='Keep the outlier', cleaner='keep', cleaner_id=1, activate=True, data=None)]),
#  ScanResult(row=0, col=num1, message='Target value '51' found in row 1, column 'num1'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Handle '{target}'', description='Handle the '{target}' value', cleaner='handle_target', cleaner_id=None, activate=True, data=None)]),
#  ScanResult(row=10, col=num1, message='Target value '51' found in row 11, column 'num1'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Handle '{target}'', description='Handle the '{target}' value', cleaner='handle_target', cleaner_id=None, activate=True, data=None)]),
#  ScanResult(row=20, col=num1, message='Target value '51' found in row 21, column 'num1'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Handle '{target}'', description='Handle the '{target}' value', cleaner='handle_target', cleaner_id=None, activate=True, data=None)])]

# %%
import random

def choose_one_action_per_scan_result(scan_results):
    for sr in scan_results:
        if sr.actions:
            chosen_action = random.choice(sr.actions)
            for action in sr.actions:
                action.activate = False
            chosen_action.activate = True
            sr.actions = [chosen_action]
    return scan_results


chosen_scan_results = choose_one_action_per_scan_result(scan_results)

chosen_scan_results
# Out:
# [ScanResult(row=10, col=-1, message='Row 11 is duplicated', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Duplication Remover', description='Keep the duplicated rows', cleaner='keep', cleaner_id=1, activate=True, data=None)]),
#  ScanResult(row=20, col=-1, message='Row 21 is duplicated', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Duplication Remover', description='Keep the duplicated rows', cleaner='keep', cleaner_id=3, activate=True, data=None)]),
#  ScanResult(row=1, col=num3, message='Missing value in row 2, column 'num3'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=3, activate=True, data=None)]),
#  ScanResult(row=5, col=num2, message='Missing value in row 6, column 'num2'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=8, activate=True, data=None)]),
#  ScanResult(row=5, col=num3, message='Missing value in row 6, column 'num3'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with mean value', cleaner='mean', cleaner_id=12, activate=True, data=None)]),
#  ScanResult(row=19, col=text, message='Missing value in row 20, column 'text'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=19, activate=True, data=None)]),
#  ScanResult(row=21, col=num2, message='Missing value in row 22, column 'num2'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with next value', cleaner='bfill', cleaner_id=26, activate=True, data=None)]),
#  ScanResult(row=24, col=text, message='Missing value in row 25, column 'text'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=31, activate=True, data=None)]),
#  ScanResult(row=25, col=num2, message='Missing value in row 26, column 'num2'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=37, activate=True, data=None)]),
#  ScanResult(row=28, col=num3, message='Missing value in row 29, column 'num3'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with mean value', cleaner='mean', cleaner_id=38, activate=True, data=None)]),
#  ScanResult(row=31, col=text, message='Missing value in row 32, column 'text'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Delete the row', cleaner='delete', cleaner_id=47, activate=True, data=None)]),
#  ScanResult(row=36, col=text, message='Missing value in row 37, column 'text'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=48, activate=True, data=None)]),
#  ScanResult(row=40, col=text, message='Missing value in row 41, column 'text'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=53, activate=True, data=None)]),
#  ScanResult(row=41, col=num3, message='Missing value in row 42, column 'num3'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with most frequent value', cleaner='mode', cleaner_id=58, activate=True, data=None)]),
#  ScanResult(row=42, col=num2, message='Missing value in row 43, column 'num2'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=65, activate=True, data=None)]),
#  ScanResult(row=44, col=num3, message='Missing value in row 45, column 'num3'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Missing Value Filler', description='Fill with previous value', cleaner='ffill', cleaner_id=71, activate=True, data=None)]),
#  ScanResult(row=11, col=num5, message='Outlier detected in column 'num5' at row 12', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Outlier Handler', description='Delete the outlier', cleaner='delete', cleaner_id=0, activate=True, data=None)]),
#  ScanResult(row=0, col=num1, message='Target value '51' found in row 1, column 'num1'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Handle '{target}'', description='Handle the '{target}' value', cleaner='handle_target', cleaner_id=None, activate=True, data=None)]),
#  ScanResult(row=10, col=num1, message='Target value '51' found in row 11, column 'num1'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Handle '{target}'', description='Handle the '{target}' value', cleaner='handle_target', cleaner_id=None, activate=True, data=None)]),
#  ScanResult(row=20, col=num1, message='Target value '51' found in row 21, column 'num1'', action_type=SRActionType.DEFAULT, actions=[ScanResultAction(title='Handle '{target}'', description='Handle the '{target}' value', cleaner='handle_target', cleaner_id=None, activate=True, data=None)])]

# %%
df1 = apply_scan_results(df1, chosen_scan_results)
df1
# Out:
#     num1       num2    cat1   cat2       num3  num4       text   bool  \
# 0     51 -20.267196  cherry    red  33.606777    98   Sample 0   True
# 1     92  11.194236  banana    red  33.606777   152   Sample 1  False
# 2     14   7.791926  cherry    red  11.881877    92   Sample 2   True
# 3     71 -11.010978   apple   blue  36.410817   145   Sample 3  False
# 4     60  11.302282   apple  green  18.389157   127   Sample 4   True
# 5     20 -20.267196  banana    red  25.080387   109   Sample 5  False
# 6     82  -3.864730  cherry    red  31.676486    81   Sample 6  False
# 7     86 -11.587702  cherry    red  26.788734   193   Sample 7  False
# 8     74   5.661128  banana   blue   4.514489    53   Sample 8   True
# 9     74  -7.044535  cherry   blue  41.765125   162   Sample 9  False
# 10    51 -20.267196  cherry    red  33.606777    98   Sample 0   True
# 11    23  -4.614657  cherry    red   2.038757   160  Sample 12   True
# 12     2   0.666573  cherry  green  29.544647    67  Sample 13  False
# 13    21  -1.762857  banana    red  33.878218    32  Sample 14   True
# 14    52  12.008928  banana    red   0.829391   141  Sample 15   True
# 15     1   6.983989   apple   blue  25.604653    20  Sample 16  False
# 16    87  -1.716288  cherry  green  11.324789    47  Sample 17   True
# 17    29  -9.071866  cherry   blue  32.258640   147  Sample 18   True
# 18    37  11.886257  cherry   blue   8.718321   127  Sample 18  False
# 19    51 -20.267196  cherry    red  33.606777    98   Sample 0   True
# 20    63   2.634860   apple    red  19.336767   134  Sample 21   True
# 21    59   2.634860  banana    red  46.836499   194  Sample 22   True
# 22    20  16.417711   apple  green   6.876047   144  Sample 23  False
# 23    57 -15.099573   apple  green  46.234681   175  Sample 26   True
# 24    21   7.215025  cherry   blue  43.866968   186  Sample 27   True
# 25    88  -8.434199  cherry  green  25.690026   114  Sample 28   True
# 26    48  -5.133254   apple   blue  32.999202   118  Sample 29  False
# 27    90  -0.435368   apple    red  40.861110    21  Sample 30   True
# 28    41 -15.630668  cherry    red  26.482529    37  Sample 32  False
# 29    91  -7.956310  cherry    red  12.092615   108  Sample 33   True
# 30    59   9.305844  banana   blue   4.655138    50  Sample 34  False
# 31    79   6.777674  banana    red  44.860788   181  Sample 35  False
# 32    14   6.984403  banana  green  45.020903     7   Sample 0   True
# 33    61   1.736021   apple  green  31.655073    26  Sample 37  False
# 34    61   6.622845  banana  green  16.951490    26  Sample 38   True
# 35    46   2.411222   apple   blue  17.460479    20  Sample 39  False
# 36    61  -1.682051   apple    red  36.297784    29  Sample 43  False
# 37    50  11.647686  banana    red  33.606777    96  Sample 41   True
# 38    54  12.334968  banana    red  44.354321    27  Sample 42  False
# 39    63  -7.696678  banana   blue  38.993777   110  Sample 43  False
# 40     2  12.121723  cherry  green  44.927709   191  Sample 44  False
# 41    50  12.334968  banana  green   4.206998   196  Sample 45  False
# 42     6 -15.741553  cherry    red   8.081436    60  Sample 46  False
# 43    20   6.379529   apple  green  44.927709    47  Sample 47   True
# 44    72 -20.444230  cherry  green  30.321453   146  Sample 48  False
# 45    38  10.694809  banana   blue   0.459853     3  Sample 49   True
#
#          num5 cat3
# 0    0.291044    Y
# 1   -5.714851    Y
# 2    1.788937    X
# 3    2.803923    X
# 4    5.415256    X
# 5    5.269010    X
# 6   -6.888347    X
# 7   -4.689125    Z
# 8    2.575176    Z
# 9    2.568930    X
# 10   0.291044    Y
# 11   2.854453    Z
# 12   5.677828    Z
# 13   4.770009    Y
# 14   3.256956    Z
# 15  -1.576346    X
# 16   3.794846    Y
# 17  -3.864126    X
# 18  -1.184093    X
# 19   0.291044    Y
# 20   0.409371    X
# 21  11.573293    Z
# 22  -9.336326    X
# 23  -2.359659    Y
# 24   5.444753    X
# 25   0.321400    Y
# 26  -5.388724    Y
# 27  -3.576519    X
# 28  -3.651833    X
# 29   1.082293    Y
# 30   0.227859    Y
# 31  -3.258002    X
# 32  10.719720    Z
# 33   3.169595    Y
# 34 -10.125713    Y
# 35   0.932272    Y
# 36  -3.308932    X
# 37   4.262167    Y
# 38  -3.962604    Z
# 39  -0.573682    Y
# 40   2.524936    Y
# 41   4.328776    Z
# 42  -6.001482    Y
# 43  -1.672506    X
# 44  -2.374727    X
# 45  -3.266646    X

# %%
from autoML_cleaning import *

df2 = auto_ML_cleaning(df2, 'cat1')
df2
# Out:
# <style type="text/css">
# #T_cd3ba_row10_col1, #T_cd3ba_row16_col1, #T_cd3ba_row18_col1, #T_cd3ba_row20_col1, #T_cd3ba_row22_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cd3ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd3ba_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cd3ba_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd3ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd3ba_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cd3ba_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd3ba_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cd3ba_row1_col1" class="data row1 col1" >bool</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cd3ba_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_cd3ba_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cd3ba_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_cd3ba_row3_col1" class="data row3 col1" >(48, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cd3ba_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_cd3ba_row4_col1" class="data row4 col1" >(49, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cd3ba_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_cd3ba_row5_col1" class="data row5 col1" >(34, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cd3ba_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_cd3ba_row6_col1" class="data row6 col1" >(15, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cd3ba_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_cd3ba_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cd3ba_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_cd3ba_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cd3ba_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_cd3ba_row9_col1" class="data row9 col1" >27.1%</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cd3ba_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_cd3ba_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cd3ba_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_cd3ba_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cd3ba_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_cd3ba_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cd3ba_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_cd3ba_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cd3ba_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_cd3ba_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cd3ba_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_cd3ba_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cd3ba_row16_col0" class="data row16 col0" >Remove multicollinearity</td>
#       <td id="T_cd3ba_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cd3ba_row17_col0" class="data row17 col0" >Multicollinearity threshold</td>
#       <td id="T_cd3ba_row17_col1" class="data row17 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cd3ba_row18_col0" class="data row18 col0" >Remove outliers</td>
#       <td id="T_cd3ba_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_cd3ba_row19_col0" class="data row19 col0" >Outliers threshold</td>
#       <td id="T_cd3ba_row19_col1" class="data row19 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_cd3ba_row20_col0" class="data row20 col0" >Fix imbalance</td>
#       <td id="T_cd3ba_row20_col1" class="data row20 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_cd3ba_row21_col0" class="data row21 col0" >Fix imbalance method</td>
#       <td id="T_cd3ba_row21_col1" class="data row21 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_cd3ba_row22_col0" class="data row22 col0" >Normalize</td>
#       <td id="T_cd3ba_row22_col1" class="data row22 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_cd3ba_row23_col0" class="data row23 col0" >Normalize method</td>
#       <td id="T_cd3ba_row23_col1" class="data row23 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_cd3ba_row24_col0" class="data row24 col0" >Fold Generator</td>
#       <td id="T_cd3ba_row24_col1" class="data row24 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_cd3ba_row25_col0" class="data row25 col0" >Fold Number</td>
#       <td id="T_cd3ba_row25_col1" class="data row25 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_cd3ba_row26_col0" class="data row26 col0" >CPU Jobs</td>
#       <td id="T_cd3ba_row26_col1" class="data row26 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_cd3ba_row27_col0" class="data row27 col0" >Use GPU</td>
#       <td id="T_cd3ba_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_cd3ba_row28_col0" class="data row28 col0" >Log Experiment</td>
#       <td id="T_cd3ba_row28_col1" class="data row28 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_cd3ba_row29_col0" class="data row29 col0" >Experiment Name</td>
#       <td id="T_cd3ba_row29_col1" class="data row29 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_cd3ba_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_cd3ba_row30_col0" class="data row30 col0" >USI
#     num1       num2    cat1   cat2       num3  num4       text       num5  \
# 0     50  11.647686  banana    red        NaN    96  Sample 41   4.262167
# 1     87  -1.716288  cherry  green  11.324789    47  Sample 17   3.794846
# 2     91  -7.956310  cherry    red  12.092614   108  Sample 33   1.082293
# 3     46   2.411222   apple   blue  17.460478    20  Sample 39   0.932272
# 4     75        NaN  cherry  green   5.673676    32  Sample 25  -8.063580
# 5     20        NaN  banana    red        NaN   109   Sample 5   5.269010
# 6     74  -7.044535  cherry   blue  41.765125   162   Sample 9   2.568930
# 7     74   5.661128  banana   blue   4.514489    53   Sample 8   2.575176
# 8     37  11.886257  cherry   blue   8.718322   127        NaN  -1.184093
# 9     79   6.777674  banana    red  44.860786   181  Sample 35  -3.258002
# 10    63  -7.696678  banana   blue  38.993778   110  Sample 43  -0.573682
# 11    14   7.791926  cherry    red  11.881877    92   Sample 2   1.788937
# 12    23  -4.614657  cherry    red   2.038757   160  Sample 12   2.854453
# 13    21   7.215024  cherry   blue  43.866966   186  Sample 27   5.444753
# 14     1   6.983989   apple   blue  25.604652    20  Sample 16  -1.576346
# 15    60  11.302282   apple  green  18.389156   127   Sample 4   5.415256
# 16    92  11.194236  banana    red        NaN   152   Sample 1  -5.714851
# 17    59   2.634861  banana    red  46.836498   194  Sample 22  11.573293
# 18    71 -11.010978   apple   blue  36.410816   145   Sample 3   2.803923
# 19    48  -5.133254   apple   blue  32.999203   118  Sample 29  -5.388724
# 20    41 -15.630668  cherry    red  26.482529    37  Sample 32  -3.651833
# 21    86 -11.587703  cherry    red  26.788734   193   Sample 7  -4.689125
# 22    21  -1.762857  banana    red  33.878220    32  Sample 14   4.770009
# 23    61   1.736021   apple  green  31.655073    26  Sample 37   3.169595
# 24    51 -20.267197  cherry    red  33.606777    98   Sample 0   0.291044
# 25    61   6.622845  banana  green  16.951490    26  Sample 38 -10.125713
# 26    50  12.334968  banana  green   4.206998   196  Sample 45   4.328776
# 27    29  -9.071866  cherry   blue  32.258640   147  Sample 18  -3.864126
# 28    14   6.984403  banana  green  45.020905     7        NaN  10.719721
# 29    82  -3.864729  cherry    red  31.676485    81   Sample 6  -6.888347
# 30    52  12.008927  banana    red   0.829391   141  Sample 15   3.256956
# 31    57 -15.099573   apple  green  46.234680   175  Sample 26  -2.359659
# 32     6 -15.741553  cherry    red   8.081436    60  Sample 46  -6.001482
# 33    32   4.608163  cherry    red  17.053318   127        NaN   3.431301
# 34    63        NaN   apple    red  19.336767   134  Sample 21   0.409371
# 35     2  12.121723  cherry  green        NaN   191  Sample 44   2.524936
# 36    72 -20.444231  cherry  green  30.321453   146  Sample 48  -2.374727
# 37    20   6.379529   apple  green  44.927708    47  Sample 47  -1.672506
# 38    38  10.694809  banana   blue   0.459853     3  Sample 49  -3.266646
# 39    20  16.417711   apple  green   6.876047   144  Sample 23  -9.336326
# 40    59   9.305844  banana   blue   4.655138    50  Sample 34   0.227859
# 41    88  -8.434199  cherry  green        NaN   114  Sample 28   0.321400
# 42    54        NaN  banana    red  44.354321    27  Sample 42  -3.962604
# 43    99  -3.531167   apple   blue   9.325926   168  Sample 11  19.263657
# 44     2   0.666573  cherry  green  29.544647    67  Sample 13   5.677828
# 45    90  -0.435368   apple    red  40.861111    21  Sample 30  -3.576519
# 46    61  -1.682051   apple    red  36.297783    29        NaN  -3.308932
# 47    58  -2.753009  cherry    red  27.760040   157        NaN   3.397989
#
#    cat3   bool
# 0     Y   True
# 1     Y   True
# 2     Y   True
# 3     Y  False
# 4     Y  False
# 5     X  False
# 6     X  False
# 7     Z   True
# 8     X  False
# 9     X  False
# 10    Y  False
# 11    X   True
# 12    Z   True
# 13    X   True
# 14    X  False
# 15    X   True
# 16    Y  False
# 17    Z   True
# 18    X  False
# 19    Y  False
# 20    X  False
# 21    Z  False
# 22    Y   True
# 23    Y  False
# 24    Y   True
# 25    Y   True
# 26    Z  False
# 27    X   True
# 28    Z   True
# 29    X  False
# 30    Z   True
# 31    Y   True
# 32    Y  False
# 33    Y   True
# 34    X   True
# 35    Y  False
# 36    X  False
# 37    X   True
# 38    X   True
# 39    X  False
# 40    Y  False
# 41    Y   True
# 42    Z  False
# 43    X  False
# 44    Z  False
# 45    X   True
# 46    X  False
# 47    Z   True
