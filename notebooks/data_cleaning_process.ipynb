# %%
from data_import import *
from data_duplicates import *
from data_missing import *
from data_outliers import *
from data_encode import *
import pandas as pd

# %%
file_path = 'path'  # replace by file path
df = pd.read_csv(file_path)

col = df.columns.values
df.columns = [x.strip() for x in col] # remove the stripping spaces

# %%
df_duplicates = scan_duplicates(df)
df_duplicates
# Out:
# ['row 9999 is duplicated', 'row 10001 is duplicated']

# %%
df_temp = remove_duplicates(df)
df_temp.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
# 1          2    15647311      Hill          608     Spain  Female  41.0
# 2          3    15619304      Onio          502    France  Female  42.0
# 3          4    15701354      Boni          699    France  Female  39.0
# 4          5    15737888  Mitchell          850     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1        1.0             1.0
# 1       1   83807.86              1        0.0             1.0
# 2       8  159660.80              3        1.0             0.0
# 3       1       0.00              2        0.0             0.0
# 4       2  125510.82              1        NaN             1.0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df_missing = scan_missing(df_temp)
df_missing
# Out:
# ['row 4 column HasCrCard has missing value',
#  'row 6 column Geography has missing value',
#  'row 8 column IsActiveMember has missing value',
#  'row 9 column Age has missing value']

# %%
df_temp = fill_missing_values_knn(df_temp)
df_temp.head(5)
# Out:
# Imputing row 1/10000 with 0 missing, elapsed time: 12.019
# Imputing row 101/10000 with 0 missing, elapsed time: 12.019
# Imputing row 201/10000 with 0 missing, elapsed time: 12.019
# Imputing row 301/10000 with 0 missing, elapsed time: 12.019
# Imputing row 401/10000 with 0 missing, elapsed time: 12.020
# Imputing row 501/10000 with 0 missing, elapsed time: 12.020
# Imputing row 601/10000 with 0 missing, elapsed time: 12.020
# Imputing row 701/10000 with 0 missing, elapsed time: 12.020
# Imputing row 801/10000 with 0 missing, elapsed time: 12.020
# Imputing row 901/10000 with 0 missing, elapsed time: 12.020
# Imputing row 1001/10000 with 0 missing, elapsed time: 12.021
# Imputing row 1101/10000 with 0 missing, elapsed time: 12.021
# Imputing row 1201/10000 with 0 missing, elapsed time: 12.021
# Imputing row 1301/10000 with 0 missing, elapsed time: 12.021
# Imputing row 1401/10000 with 0 missing, elapsed time: 12.021
# Imputing row 1501/10000 with 0 missing, elapsed time: 12.021
# ...

# %%
df_outliers = scan_outliers(df_temp)
df_outliers
# Out:
# ['Row 2 has outlier',
#  'Row 7 has outlier',
#  'Row 30 has outlier',
#  'Row 35 has outlier',
#  'Row 41 has outlier',
#  'Row 43 has outlier',
#  'Row 57 has outlier',
#  'Row 58 has outlier',
#  'Row 70 has outlier',
#  'Row 85 has outlier',
#  'Row 88 has outlier',
#  'Row 90 has outlier',
#  'Row 104 has outlier',
#  'Row 114 has outlier',
#  'Row 126 has outlier',
#  'Row 127 has outlier',
#  'Row 139 has outlier',
#  'Row 149 has outlier',
#  'Row 202 has outlier',
#  'Row 223 has outlier',
#  'Row 230 has outlier',
#  'Row 238 has outlier',
#  'Row 252 has outlier',
#  'Row 271 has outlier',
#  'Row 276 has outlier',
#  'Row 297 has outlier',
#  'Row 313 has outlier',
#  'Row 361 has outlier',
#  'Row 376 has outlier',
#  'Row 379 has outlier',
#  'Row 406 has outlier',
#  'Row 413 has outlier',
#  'Row 416 has outlier',
#  'Row 458 has outlier',
#  'Row 467 has outlier',
#  'Row 494 has outlier',
#  'Row 499 has outlier',
#  'Row 516 has outlier',
#  'Row 520 has outlier',
# ...

# %%
df_temp = remove_outliers(df_temp)
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9500 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        9500 non-null   int64
#  1   CustomerId       9500 non-null   int64
#  2   Surname          9500 non-null   object
#  3   CreditScore      9500 non-null   int64
#  4   Geography        9500 non-null   object
#  5   Gender           9500 non-null   object
#  6   Age              9500 non-null   float64
#  7   Tenure           9500 non-null   int64
#  8   Balance          9500 non-null   float64
#  9   NumOfProducts    9500 non-null   int64
#  10  HasCrCard        9500 non-null   float64
#  11  IsActiveMember   9500 non-null   float64
#  12  EstimatedSalary  9500 non-null   float64
#  13  Exited           9500 non-null   int64
# dtypes: float64(5), int64(6), object(3)
# memory usage: 1.1+ MB

# %%
df_result = encode_categorical_features(df_temp)
# Out:
# Column 'Surname' has 2856 unique values, keeping original.
