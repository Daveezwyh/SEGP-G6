# %%
from data_scan import *
from data_clean import *
from data_encode import *
import pandas as pd

# %%
# file_path = 'D:\\codes\\pythoncodes\\Churn_Modelling.csv'  # replace by file path
# df = pd.read_csv(file_path)

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Lala'],
    'Gender': ['M','M','F',None,'M','M'],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'New York'],
    'Score': [1,5,87,88,92,99]
}

df = pd.DataFrame(data)

col = df.columns.values
df.columns = [x.strip() for x in col] # remove the stripping spaces

# %%
scan_result = scan_df_for_duplicates(df)
scan_result
# Out:
# []

# %%
scan_result = scan_df_for_missing(df)
scan_result
# Out:
# [ScanResult(row=3, col=1, message='Missing value in row 4, column Gender', cleaner='fill_missing', activate=True)]

# %%
scan_result = scan_df_for_outliers(df)
scan_result
# Out:
# [ScanResult(row=0, col=-1, message='Row 1 contains an outlier', cleaner='outlier_removal', activate=True)]

# %%
df_new = remove_duplicates(df)

# %%
df_new = fill_missing_values_knn(df_new)
# Out:
# Imputing row 1/6 with 0 missing, elapsed time: 0.001
# d:\venv\data_cleaning\Lib\site-packages\fancyimpute\solver.py:55: UserWarning: Input matrix is not missing any values
#   warnings.warn("Input matrix is not missing any values")
# d:\SEGP-G6\notebooks\data_clean.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_filled[column].fillna(most_frequent_value, inplace=True)
# d:\SEGP-G6\notebooks\data_clean.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_filled[column].fillna(most_frequent_value, inplace=True)
# d:\SEGP-G6\notebooks\data_clean.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_filled[column].fillna(most_frequent_value, inplace=True)

# %%
df_new = remove_outliers(df_new)

# %%
df_final = encode_categorical_features(df_new)

# %%
df_new
# Out:
#       Name Gender         City  Score
# 1      Bob      M  Los Angeles      5
# 2  Charlie      F      Chicago     87
# 3    David      M      Houston     88
# 4      Eve      M      Phoenix     92
# 5     Lala      M     New York     99

# %%
scan_for_target(df_new, "o")
# Out:
# []
