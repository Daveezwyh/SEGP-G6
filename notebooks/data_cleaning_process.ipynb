# %%
from data_import import *
from data_display import *
from data_duplicates import *
from data_outliers import *
from data_missing import *
from data_encode import *
from data_remove import *

# %%
file_path = 'Churn_Modelling.csv'  # replace by file path
df = load_data(file_path)

col = df.columns.values
df.columns = [x.strip() for x in col] # remove the stripping spaces

# %%
choice = "head"
num_rows = 1
display_data(df, choice, num_rows)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
#
#    Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       2      0.0              1        1.0             1.0        101348.88
#
#    Exited
# 0       1

# %%
df_duplicates = find_duplicates(df)
df_duplicates
# Out:
#        RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 9998        9999    15682355  Sabbatini          772   Germany    Male  42.0
# 9999        9999    15682355  Sabbatini          772   Germany    Male  42.0
# 10000      10000    15628319     Walker          792    France  Female  28.0
# 10001      10000    15628319     Walker          792    France  Female  28.0
#
#        Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9998        3   75075.31              2        1.0             0.0
# 9999        3   75075.31              2        1.0             0.0
# 10000       4  130142.79              1        1.0             0.0
# 10001       4  130142.79              1        1.0             0.0
#
#        EstimatedSalary  Exited
# 9998          92888.52       1
# 9999          92888.52       1
# 10000         38190.78       0
# 10001         38190.78       0

# %%
df_new = remove_rows(df, 9998)
display_data(df_new, "tail", 10)
# Out:
#        RowNumber  CustomerId      Surname  CreditScore Geography  Gender  \
# 9990        9991    15798964   Nkemakonam          714   Germany    Male
# 9991        9992    15769959  Ajuluchukwu          597    France  Female
# 9992        9993    15657105  Chukwualuka          726     Spain    Male
# 9993        9994    15569266       Rahman          644    France    Male
# 9994        9995    15719294         Wood          800    France  Female
# 9995        9996    15606229     Obijiaku          771    France    Male
# 9996        9997    15569892    Johnstone          516    France    Male
# 9997        9998    15584532          Liu          709    France  Female
# 9999        9999    15682355    Sabbatini          772   Germany    Male
# 10001      10000    15628319       Walker          792    France  Female
#
#         Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9990   33.0       3   35016.60              1        1.0             0.0
# ...

# %%
outliers_dict = {}

for column in df.select_dtypes(include=np.number).columns:
    df_outliers = find_outliers_percentile(df, column)
            
    # Only add columns with outliers to the dictionary
    if not df_outliers.empty:
        outliers_dict[column] = df_outliers

outliers_dict["Age"]
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 57           58    15647091         Endrizzi          725   Germany    Male
# 85           86    15805254          Ndukaku          652     Spain  Female
# 158         159    15589975          Maclean          646    France  Female
# 233         234    15723886            Fiore          767   Germany    Male
# 252         253    15793726        Matveyeva          681    France  Female
# ...         ...         ...              ...          ...       ...     ...
# 9782       9783    15728829           Weigel          509    France    Male
# 9894       9895    15704795            Vagin          521    France  Female
# 9932       9933    15813451  Fleetwood-Smith          677     Spain    Male
# 9936       9937    15653037            Parks          609    France    Male
# 9940       9941    15791972      Bergamaschi          748    France  Female
#
# ...

# %%
df_no_outliers, df_outliers = remove_outliers(df_no_duplicates, 'column_name') #need to get changed, outliers may be needed for other purposes
df_no_empty = fill_missing_with(df_no_outliers, 'column_name') #for different columns we need different functions
df_encoded  = encode_categorical_features(df_no_empty)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_no_outliers, df_outliers = remove_outliers(df_no_duplicates, 'column_name') #need to get changed, outliers may be needed for other purposes
#       2 df_no_empty = fill_missing_with(df_no_outliers, 'column_name') #for different columns we need different functions
#       3 df_encoded  = encode_categorical_features(df_no_empty)
#
# NameError: name 'remove_outliers' is not defined
